# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#Job Application Helper - AI Agent(Capstone project)

# %% [markdown]
# ## 1. Introduction

# %%
def show_intro():
    print("""
🧠💁finding the right job and felling out job application 
form can be confusing for many student or fresher.
many people struggle with:
.Resume summry
.job title
.Skills
.Authorization
.HR term 
  """)

show_intro()
# Out:
# 🧠💁finding the right job and felling out job application
# form can be confusing for many student or fresher.
# many people struggle with:
# .Resume summry
# .job title
# .Skills
# .Authorization
# .HR term

# %% [markdown]
# ## 2 . Install & Import Libraries

# %%
from google import genai
import json

# %% [markdown]
# ## 3 . Gemini API Setup

# %%
from google import genai
from kaggle_secrets import UserSecretsClient

user_secrets = UserSecretsClient()
api_key = user_secrets.get_secret("GEMINI_API_KEY")

client = genai.Client(api_key=api_key)

# %% [markdown]
# ## 4 . Agent Function

# %%
from google import genai
client = genai.Client(api_key="YOUR_API-KEY")
def job_application_agent(user_input):
    Prompt = f"""
    you are ajpb Application Helper AI Agent.
    your job:
    1.🤗⚙️ Help user understand job Application questions.
    2.⚙️Give correct answer, explanation,and examples.
    3.Provide answer in simple English + Hindi mix.
    
    User question: {user_input}
    Give best possible answer.
    """
    response = client.models.generate_content(
        model="🤖gemini-2.0-flash",
        contents=prompt
    )
    return response.text

# %% [markdown]
# ## 5 . User input function

# %%
def ask_agent():
  while true:
     user_input=input("👤Ask your Job Application question(or type'exit'to quite):")
     if user_input.lower()=='exit':
          print("🙏✨Thank you forusingJob Application Helper AI Agent!")
          break
          response=job_application-agent(user_input)
          print("\nAI Agent:\n","\n")

# %% [markdown]
# ## 6 . Test chatbox

# %%
def ask_agent(user_input):
    response = f"🤖AI Agent Response: You said - {user_input}"
    return response

# %% [markdown]
# ## 7. Improve AI Responses

# %%
conversation_history = []
def improved_agent(user_query):
    conversation_history.append({"role":"user","query": user_query})
    prompt = "👍🤗You are a job Application helper AI.\n"
    prompt += "🎯Conversation istory:\n"
    for chat in conversation_history:
        prompt += f"User:{chat['query']}\n"
        prompt += f"Now answer this professionally:\n{user_query}"
        response = agent(prompt) # Using agent function
    conversation_history.append({"role":"assistant🙏",
"response":response})
    return response

# %% [markdown]
# ## 8 . Add Resume Review Feature

# %%
def resume_review(resume_text):
    prompt = f"""
   🎯 You are an expert HR. Analyze the followling resume and suggest improvements.
    Resume Text:
    {resume_text}
    Give professional feedback in bullet points✨.
    """
    response = agent(prompt)
    return response

# %% [markdown]
# ## 9 . Add Job Description Matcing Feature

# %%
def Job_matching(resume_text,Job_description):
    prompt = f"""
   ✨🎯 compare the following resume with job description and rate suitability.

    Resume:
    {resume_text}

    Job Description:
    {Job_Description}

    Give:
    1. Matc percentage,
    2. Strengths,
    3. Weak skills,
    4. Final Recommendation.
    """
    response = agent(prompt)
    return response

# %% [markdown]
# ## 10. Final Chat Application

# %%
def job_application_chatbot():
    print("Welcome to Job Application Helper AI!")
    print("🧠You can ask: Resume review, Job matching, Interview help, Cover latter.")

    while True:
       user_input=input("\nYou:") 

       if user_input.lower()in["exit","quit"]:
           print("🤖AI:🙏Thank you for using Job Application Helper.Good luck!✌️🙌")
           break

       elif"resume"in user_input.lower():
           print("🤖AI:🕸️🙏Please paste your resume text:")

           resume = {
               "name": input("Priya Goswami: "),
               "education": input("B.Tech: "),
               "skills": input("Google 5-Day AI Agent","HTML","CSS","C","C++","Data structure","java","Python", "Java script","Communication skills","Problem solving","React.js: " ),
               "project": input("Portfolio","Single page Application✨👍: "),
               "experience": input("Fresher/Student:"),
               
           }
           print("🤖AI:,resume saved succesfully!✨😍")

       elif"Job match"in user_input.lower()or"job matching"in user_input.lower:
              job_desc=input("AI:Please paste job description:")
              resume_text=input()
              print("🤖AI:",job_matching(resume_text,job_desc))
       else:
           print("🤖AI:",improved_agent(user_input))
